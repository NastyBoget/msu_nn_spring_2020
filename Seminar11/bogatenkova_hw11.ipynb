# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import torchvision
import matplotlib.pyplot as plt
import numpy as np

from torch.autograd import Variable

# %% [markdown]
# ### Creating config object (argparse workaround)

# %%
class Config:
    pass

config = Config()
config.mnist_path = None
config.batch_size = 16
config.num_workers = 3
config.num_epochs = 10
config.noise_size = 50
config.print_freq = 500

# %% [markdown]
# ### Create dataloder

# %%
train = torchvision.datasets.FashionMNIST("fashion_mnist", train=True, transform=torchvision.transforms.ToTensor(), download=True)

# %%
dataloader = DataLoader(train, batch_size=16, shuffle=True)

# %%
len(dataloader)
# Out:
# 3750

# %%
for image, cat in dataloader:
    break

# %%
image.size()
# Out:
# torch.Size([16, 1, 28, 28])

# %%
28*28
# Out:
# 784

# %%
plt.figure(figsize=(6, 7))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(image[i].detach().numpy().reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.axis('off')

# %% [markdown]
# ### Create generator and discriminator

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential( 
            nn.Linear(config.noise_size, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 28*28),
            nn.Sigmoid())
        
    def forward(self, x):
        return self.model(x)
    
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(28*28, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 1), 
            nn.Sigmoid())
    def forward(self, x):
        return self.model(x)

# %%
generator = Generator()
discriminator = Discriminator()

# %% [markdown]
# ### Create optimizers and loss

# %%
optim_G = optim.Adam(params=generator.parameters(), lr=0.0001)
optim_D = optim.Adam(params=discriminator.parameters(), lr=0.0001)

criterion = nn.BCELoss()

# %% [markdown]
# ### Create necessary variables

# %%
input = Variable(torch.FloatTensor(config.batch_size, 28*28))
noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size))
fixed_noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size).normal_(0, 1))
label = Variable(torch.FloatTensor(config.batch_size))
real_label = 1
fake_label = 0

# %% [markdown]
# ### Задание
#
# 1) Посмотрите на реализацию GAN. Постройте интерполяцию между какими-нибудь двумя сгенерированными картинками. (Опционально)Добавьте свертки в генератор и дискриминатор, как в статье про DCGAN.
#
# 2) Поменяйте ее, чтобы получился LSGAN https://arxiv.org/pdf/1611.04076v2.pdf
#
# 3) Добавьте к обучению GAN условие на метку, продемонстрируйте условную генерацию. https://arxiv.org/pdf/1411.1784.pdf
#
# 4) Напишите отчет что попробовали, какие результаты получили, как вам кажется надо обучать GAN, чтобы добиться сходимости?
#
# В каждом пункте постройте графики функций потерь.

# %% [markdown]
# ### GAN

# %%
ERRD_x = np.zeros(config.num_epochs)
ERRD_z = np.zeros(config.num_epochs)
ERRG = np.zeros(config.num_epochs)
N = len(dataloader)

for epoch in range(config.num_epochs):
    for iteration, (images, cat) in enumerate(dataloader):
        ####### 
        # Discriminator stage: maximize log(D(x)) + log(1 - D(G(z))) 
        #######
        discriminator.zero_grad()
        
        # real
        label.data.fill_(real_label)
        input_data = images.view(images.shape[0], -1)
        output = discriminator(input_data)
        errD_x = criterion(output, label)
        ERRD_x[epoch] += errD_x.item()
        errD_x.backward()
        
        # fake 
        noise.data.normal_(0, 1)
        fake = generator(noise)
        label.data.fill_(fake_label)
        output = discriminator(fake.detach())
        errD_z = criterion(output, label)
        ERRD_z[epoch] += errD_z.item()
        errD_z.backward()
        
        optim_D.step()
        
        ####### 
        # Generator stage: maximize log(D(G(x))
        #######
        generator.zero_grad()
        label.data.fill_(real_label)
        output = discriminator(fake)
        errG = criterion(output, label)
        ERRG[epoch] += errG.item()
        errG.backward()
        
        optim_G.step()
        
        if (iteration+1) % config.print_freq == 0:
            print('Epoch:{} Iter: {} errD_x: {:.2f} errD_z: {:.2f} errG: {:.2f}'.format(epoch+1,
                                                                                        iteration+1, 
                                                                                        errD_x.item(),
                                                                                        errD_z.item(), 
                                                                                        errG.item()))
# Out:
# /home/ubuntu/miniconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# Epoch:1 Iter: 100 errD_x: 0.13 errD_z: 0.10 errG: 2.45
# Epoch:1 Iter: 200 errD_x: 0.25 errD_z: 0.28 errG: 1.72
# Epoch:1 Iter: 300 errD_x: 0.27 errD_z: 0.13 errG: 2.32
# Epoch:1 Iter: 400 errD_x: 0.19 errD_z: 0.09 errG: 2.58
# Epoch:1 Iter: 500 errD_x: 0.11 errD_z: 0.09 errG: 2.54
# Epoch:1 Iter: 600 errD_x: 0.32 errD_z: 0.08 errG: 2.77
# Epoch:1 Iter: 700 errD_x: 0.01 errD_z: 0.12 errG: 2.61
# Epoch:1 Iter: 800 errD_x: 0.08 errD_z: 0.19 errG: 2.07
# Epoch:1 Iter: 900 errD_x: 0.09 errD_z: 0.17 errG: 2.18
# Epoch:1 Iter: 1000 errD_x: 0.18 errD_z: 0.23 errG: 1.94
# Epoch:1 Iter: 1100 errD_x: 0.12 errD_z: 0.34 errG: 1.94
# Epoch:1 Iter: 1200 errD_x: 0.14 errD_z: 0.13 errG: 2.63
# Epoch:1 Iter: 1300 errD_x: 0.20 errD_z: 0.31 errG: 1.63
# Epoch:1 Iter: 1400 errD_x: 0.31 errD_z: 0.19 errG: 2.03
# Epoch:1 Iter: 1500 errD_x: 0.10 errD_z: 0.38 errG: 1.94
# Epoch:1 Iter: 1600 errD_x: 0.19 errD_z: 0.15 errG: 2.69
# Epoch:1 Iter: 1700 errD_x: 0.20 errD_z: 0.24 errG: 2.36
# Epoch:1 Iter: 1800 errD_x: 0.22 errD_z: 0.22 errG: 2.13
# Epoch:1 Iter: 1900 errD_x: 0.92 errD_z: 0.11 errG: 2.76
# Epoch:1 Iter: 2000 errD_x: 0.11 errD_z: 0.11 errG: 2.86
# Epoch:1 Iter: 2100 errD_x: 0.15 errD_z: 0.20 errG: 2.36
# Epoch:1 Iter: 2200 errD_x: 0.13 errD_z: 0.13 errG: 2.86
# Epoch:1 Iter: 2300 errD_x: 0.13 errD_z: 0.10 errG: 3.15
# Epoch:1 Iter: 2400 errD_x: 0.04 errD_z: 0.20 errG: 2.54
# Epoch:1 Iter: 2500 errD_x: 0.14 errD_z: 0.13 errG: 3.18
# Epoch:1 Iter: 2600 errD_x: 0.04 errD_z: 0.03 errG: 4.09
# Epoch:1 Iter: 2700 errD_x: 0.15 errD_z: 0.11 errG: 3.28
# Epoch:1 Iter: 2800 errD_x: 0.09 errD_z: 0.06 errG: 3.87
# Epoch:1 Iter: 2900 errD_x: 0.02 errD_z: 0.08 errG: 3.24
# Epoch:1 Iter: 3000 errD_x: 0.07 errD_z: 0.03 errG: 4.77
# Epoch:1 Iter: 3100 errD_x: 0.01 errD_z: 0.03 errG: 4.16
].detach().numpy().reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.axis('off')

# %%
plt.figure(figsize=(10, 5))
plt.plot(ERRD_x, label="real")
plt.plot(ERRD_z, label="fake")
plt.plot(ERRG, label="generator")
plt.legend()
plt.show()

# %% [markdown]
# ### LSGAN

# %%
optim_G = optim.Adam(params=generator.parameters(), lr=0.0001)
optim_D = optim.Adam(params=discriminator.parameters(), lr=0.0001)

criterion = nn.MSELoss()

input = Variable(torch.FloatTensor(config.batch_size, 28*28))
noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size))
fixed_noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size).normal_(0, 1))
label = Variable(torch.FloatTensor(config.batch_size))
real_label = 1
fake_label = 0

# %%
ERRD_x = np.zeros(config.num_epochs)
ERRD_z = np.zeros(config.num_epochs)
ERRG = np.zeros(config.num_epochs)
N = len(dataloader)

for epoch in range(config.num_epochs):
    for iteration, (images, cat) in enumerate(dataloader):
        ####### 
        # Discriminator stage: maximize (D(x) - 1)^2 + (D(G(z)))^2
        #######
        discriminator.zero_grad()
        
        # real
        label.data.fill_(real_label)
        input_data = images.view(images.shape[0], -1)
        output = discriminator(input_data)
        errD_x = criterion(output, label)
        ERRD_x[epoch] += errD_x.item()
        errD_x.backward()
        
        # fake 
        noise.data.normal_(0, 1)
        fake = generator(noise)
        label.data.fill_(fake_label)
        output = discriminator(fake.detach())
        errD_z = criterion(output, label)
        ERRD_z[epoch] += errD_z.item()
        errD_z.backward()
        
        optim_D.step()
        
        ####### 
        # Generator stage: maximize (D(G(x) - 1)^2
        #######
        generator.zero_grad()
        label.data.fill_(real_label)
        output = discriminator(fake)
        errG = criterion(output, label)
        ERRG[epoch] += errG.item()
        errG.backward()
        
        optim_G.step()
        
        if (iteration+1) % config.print_freq == 0:
            print('Epoch:{} Iter: {} errD_x: {:.2f} errD_z: {:.2f} errG: {:.2f}'.format(epoch+1,
                                                                                        iteration+1, 
                                                                                        errD_x.item(),
                                                                                        errD_z.item(),
                                                                                        errG.item()))
# Out:
# /home/ubuntu/miniconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch:1 Iter: 500 errD_x: 0.08 errD_z: 0.03 errG: 0.72
# Epoch:1 Iter: 1000 errD_x: 0.11 errD_z: 0.06 errG: 0.69
# Epoch:1 Iter: 1500 errD_x: 0.01 errD_z: 0.09 errG: 0.65
# Epoch:1 Iter: 2000 errD_x: 0.03 errD_z: 0.01 errG: 0.91
# Epoch:1 Iter: 2500 errD_x: 0.00 errD_z: 0.05 errG: 0.90
# Epoch:1 Iter: 3000 errD_x: 0.08 errD_z: 0.01 errG: 0.82
# Epoch:1 Iter: 3500 errD_x: 0.01 errD_z: 0.02 errG: 0.81
# Epoch:2 Iter: 500 errD_x: 0.03 errD_z: 0.00 errG: 0.97
# Epoch:2 Iter: 1000 errD_x: 0.02 errD_z: 0.03 errG: 0.83
# Epoch:2 Iter: 1500 errD_x: 0.10 errD_z: 0.03 errG: 0.80
# Epoch:2 Iter: 2000 errD_x: 0.13 errD_z: 0.04 errG: 0.75
# Epoch:2 Iter: 2500 errD_x: 0.14 errD_z: 0.08 errG: 0.74
# Epoch:2 Iter: 3000 errD_x: 0.04 errD_z: 0.06 errG: 0.73
# Epoch:2 Iter: 3500 errD_x: 0.05 errD_z: 0.09 errG: 0.69
# Epoch:3 Iter: 500 errD_x: 0.03 errD_z: 0.09 errG: 0.68
# Epoch:3 Iter: 1000 errD_x: 0.14 errD_z: 0.04 errG: 0.81
# Epoch:8 Iter: 1500 errD_x: 0.10 errD_z: 0.08 errG: 0.61
# Epoch:8 Iter: 2000 errD_x: 0.06 errD_z: 0.09 errG: 0.71
# Epoch:8 Iter: 2500 errD_x: 0.28 errD_z: 0.07 errG: 0.66
# Epoch:8 Iter: 3000 errD_x: 0.10 errD_z: 0.11 errG: 0.65
# Epoch:8 Iter: 3500 errD_x: 0.68 errD_z: 0.01 errG: 0.92
# Epoch:9 Iter: 500 errD_x: 0.22 errD_z: 0.07 errG: 0.66
# Epoch:9 Iter: 1000 errD_x: 0.20 errD_z: 0.02 errG: 0.75
# Epoch:9 Iter: 1500 errD_x: 0.17 errD_z: 0.14 errG: 0.57
# Epoch:9 Iter: 2000 errD_x: 0.08 errD_z: 0.11 errG: 0.56
# Epoch:9 Iter: 2500 errD_x: 0.16 errD_z: 0.04 errG: 0.75
# Epoch:9 Iter: 3000 errD_x: 0.14 errD_z: 0.12 errG: 0.49
# Epoch:9 Iter: 3500 errD_x: 0.37 errD_z: 0.08 errG: 0.57
# Epoch:10 Iter: 500 errD_x: 0.13 errD_z: 0.11 errG: 0.52
# Epoch:10 Iter: 1000 errD_x: 0.18 errD_z: 0.08 errG: 0.66
# Epoch:10 Iter: 1500 errD_x: 0.13 errD_z: 0.05 errG: 0.79
# Epoch:10 Iter: 2000 errD_x: 0.07 errD_z: 0.03 errG: 0.70
# Epoch:10 Iter: 2500 errD_x: 0.07 errD_z: 0.05 errG: 0.74
# Epoch:10 Iter: 3000 errD_x: 0.34 errD_z: 0.11 errG: 0.51
# Epoch:10 Iter: 3500 errD_x: 0.26 errD_z: 0.03 errG: 0.74

# %%
noise.data.normal_(0, 1)
fake = generator(noise)

plt.figure(figsize=(6, 7))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(fake[i].detach().numpy().reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.axis('off')

# %%
plt.figure(figsize=(10, 5))
plt.plot(ERRD_x, label="real")
plt.plot(ERRD_z, label="fake")
plt.plot(ERRG, label="generator")
plt.legend()
plt.show()

# %% [markdown]
# ### Interpolation

# %% [markdown]
# https://machinelearningmastery.com/how-to-interpolate-and-perform-vector-arithmetic-with-faces-using-a-generative-adversarial-network/

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples, n_classes=10):
    # generate points in the latent space
    x_input = np.random.randn(latent_dim * n_samples)
    # reshape into a batch of inputs for the network
    z_input = x_input.reshape(n_samples, latent_dim)
    return z_input
 
# uniform interpolation between two points in latent space
def interpolate_points(p1, p2, n_steps=10):
    # interpolate ratios between the points
    ratios = np.linspace(0, 1, num=n_steps)
    # linear interpolate vectors
    vectors = list()
    for ratio in ratios:
        v = (1.0 - ratio) * p1 + ratio * p2
        vectors.append(v)
    return np.asarray(vectors)
 
# create a plot of generated images
def plot_generated(examples, n):
    plt.figure(figsize=(15, 5))
    # plot images
    for i in range(n):
        # define subplot
        plt.subplot(1, n, 1 + i)
        # turn off axis
        plt.axis('off')
        # plot raw pixel data
        plt.imshow(examples[i].detach().numpy().reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.show()

# generate points in latent space
pts = generate_latent_points(config.noise_size, 2)
# interpolate points in latent space
interpolated = interpolate_points(pts[0], pts[1])
# generate images
X = generator(torch.FloatTensor(interpolated))
# plot the result
plot_generated(X, 10)

# %% [markdown]
# ### Conditional GAN

# %% [markdown]
# https://machinelearningmastery.com/how-to-develop-a-conditional-generative-adversarial-network-from-scratch/

# %%
class CondGenerator(nn.Module):
    def __init__(self):
        super(CondGenerator, self).__init__()
        self.model = nn.Sequential( 
            nn.Linear(config.noise_size + 10, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 28*28),
            nn.Sigmoid())
        self.label_emb = nn.Embedding(10, 10)
        
    def forward(self, x, labels):
        c = self.label_emb(labels)
        x = torch.cat([x, c], 1)
        return self.model(x)
    
class CondDiscriminator(nn.Module):
    def __init__(self):
        super(CondDiscriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(28*28 + 10, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 1), 
            nn.Sigmoid())
        self.label_emb = nn.Embedding(10, 10)
    def forward(self, x, labels):
        c = self.label_emb(labels)
        x = torch.cat([x, c], 1)
        return self.model(x)

# %%
generator = CondGenerator()
discriminator = CondDiscriminator()

# %%
optim_G = optim.Adam(params=generator.parameters(), lr=0.0001)
optim_D = optim.Adam(params=discriminator.parameters(), lr=0.0001)

criterion = nn.BCELoss()

input = Variable(torch.FloatTensor(config.batch_size, 28*28))
noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size))
fixed_noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size).normal_(0, 1))
label = Variable(torch.FloatTensor(config.batch_size))
real_label = 1
fake_label = 0

# %%
ERRD_x = np.zeros(config.num_epochs)
ERRD_z = np.zeros(config.num_epochs)
ERRG = np.zeros(config.num_epochs)
N = len(dataloader)

for epoch in range(10):
    for iteration, (images, cat) in enumerate(dataloader):
        ####### 
        # Discriminator stage: maximize log(D(x)) + log(1 - D(G(z))) 
        #######
        discriminator.zero_grad()
        
        # real
        label.data.fill_(real_label)
        input_data = images.view(images.shape[0], -1)
        output = discriminator(input_data, cat)
        errD_x = criterion(output, label)
        ERRD_x[epoch] += errD_x.item()
        errD_x.backward()
        
        # fake 
        fake_cat = Variable(torch.LongTensor(np.random.randint(0, 10, config.batch_size)))
        label.data.fill_(fake_label)
        noise.data.normal_(0, 1)
        fake = generator(noise, fake_cat)
        output = discriminator(fake.detach(), fake_cat)
        errD_z = criterion(output, label)
        ERRD_z[epoch] += errD_z.item()
        errD_z.backward()

        optim_D.step()

        ####### 
        # Generator stage: maximize log(D(G(x))
        #######
        label.data.fill_(real_label)
        generator.zero_grad()
        output = discriminator(fake, fake_cat)
        errG = criterion(output, label)
        ERRG[epoch] += errG.item()
        errG.backward()

        optim_G.step()
        
        if (iteration+1) % config.print_freq == 0:
            print('Epoch:{} Iter: {} errD_x: {:.2f} errD_z: {:.2f} errG: {:.2f}'.format(epoch+1,
                                                                                        iteration+1, 
                                                                                        errD_x.item(),
                                                                                        errD_z.item(), 
                                                                                        errG.item()))
# Out:
# /home/ubuntu/miniconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# Epoch:1 Iter: 500 errD_x: 0.10 errD_z: 0.12 errG: 2.41
# Epoch:1 Iter: 1000 errD_x: 0.34 errD_z: 0.19 errG: 2.10
# Epoch:1 Iter: 1500 errD_x: 0.09 errD_z: 0.23 errG: 2.30
# Epoch:1 Iter: 2000 errD_x: 0.11 errD_z: 0.07 errG: 3.41
# Epoch:1 Iter: 2500 errD_x: 0.02 errD_z: 0.02 errG: 4.80
# Epoch:1 Iter: 3000 errD_x: 0.10 errD_z: 0.02 errG: 4.01
# Epoch:1 Iter: 3500 errD_x: 0.04 errD_z: 0.09 errG: 3.20
# Epoch:2 Iter: 500 errD_x: 0.02 errD_z: 0.06 errG: 3.57
# Epoch:2 Iter: 1000 errD_x: 0.23 errD_z: 0.10 errG: 3.29
# Epoch:2 Iter: 1500 errD_x: 0.18 errD_z: 0.04 errG: 4.03
# Epoch:2 Iter: 2000 errD_x: 0.00 errD_z: 0.15 errG: 3.19
# Epoch:2 Iter: 2500 errD_x: 0.06 errD_z: 0.09 errG: 3.45
# Epoch:2 Iter: 3000 errD_x: 0.27 errD_z: 0.06 errG: 4.05
# Epoch:2 Iter: 3500 errD_x: 0.17 errD_z: 0.05 errG: 4.15
# Epoch:3 Iter: 500 errD_x: 0.08 errD_z: 0.03 errG: 4.05
# Epoch:3 Iter: 1000 errD_x: 0.32 errD_z: 0.04 errG: 3.92
# Epoch:3 Iter: 1500 errD_x: 0.14 errD_z: 0.23 errG: 2.69
# Epoch:3 Iter: 2000 errD_x: 0.29 errD_z: 0.04 errG: 4.58
# Epoch:3 Iter: 2500 errD_x: 0.28 errD_z: 0.19 errG: 3.45
# Epoch:3 Iter: 3000 errD_x: 0.59 errD_z: 0.01 errG: 5.04
# Epoch:3 Iter: 3500 errD_x: 0.08 errD_z: 0.02 errG: 5.88
# Epoch:4 Iter: 500 errD_x: 0.04 errD_z: 0.09 errG: 3.51
# Epoch:4 Iter: 1000 errD_x: 0.12 errD_z: 0.06 errG: 4.29
# Epoch:4 Iter: 1500 errD_x: 0.03 errD_z: 0.32 errG: 3.23
# Epoch:4 Iter: 2000 errD_x: 0.59 errD_z: 0.10 errG: 3.71
# Epoch:4 Iter: 2500 errD_x: 0.16 errD_z: 0.04 errG: 3.99
# Epoch:4 Iter: 3000 errD_x: 0.21 errD_z: 0.07 errG: 3.62
# Epoch:4 Iter: 3500 errD_x: 0.06 errD_z: 0.11 errG: 4.01
# Epoch:5 Iter: 500 errD_x: 0.54 errD_z: 0.02 errG: 4.79
# Epoch:5 Iter: 1000 errD_x: 0.16 errD_z: 0.10 errG: 4.02
# Epoch:5 Iter: 1500 errD_x: 0.03 errD_z: 0.18 errG: 3.28
# Epoch:5 Iter: 2000 errD_x: 0.10 errD_z: 0.09 errG: 3.93
# Epoch:5 Iter: 2500 errD_x: 0.30 errD_z: 0.15 errG: 3.43
# Epoch:5 Iter: 3000 errD_x: 0.64 errD_z: 0.02 errG: 4.92
# Epoch:5 Iter: 3500 errD_x: 0.14 errD_z: 0.19 errG: 2.92
# Epoch:6 Iter: 500 errD_x: 0.06 errD_z: 0.10 errG: 4.23
# Epoch:6 Iter: 1000 errD_x: 0.29 errD_z: 0.17 errG: 2.73
# Epoch:6 Iter: 1500 errD_x: 0.25 errD_z: 0.07 errG: 3.30
# Epoch:6 Iter: 2000 errD_x: 0.39 errD_z: 0.10 errG: 4.25
# Epoch:6 Iter: 2500 errD_x: 0.93 errD_z: 0.13 errG: 3.47
# Epoch:6 Iter: 3000 errD_x: 0.37 errD_z: 0.30 errG: 1.91
# Epoch:6 Iter: 3500 errD_x: 0.44 errD_z: 0.07 errG: 3.60
# Epoch:7 Iter: 500 errD_x: 0.30 errD_z: 0.29 errG: 1.97
# Epoch:7 Iter: 1000 errD_x: 0.32 errD_z: 0.11 errG: 3.16
# Epoch:7 Iter: 1500 errD_x: 0.16 errD_z: 0.13 errG: 3.57
# Epoch:7 Iter: 2000 errD_x: 0.32 errD_z: 0.25 errG: 2.10
# Epoch:7 Iter: 2500 errD_x: 0.50 errD_z: 0.07 errG: 3.26
# Epoch:7 Iter: 3000 errD_x: 0.32 errD_z: 0.30 errG: 2.52
# Epoch:7 Iter: 3500 errD_x: 0.27 errD_z: 0.15 errG: 3.06
# Epoch:8 Iter: 500 errD_x: 0.22 errD_z: 0.18 errG: 2.75
# Epoch:8 Iter: 1000 errD_x: 0.40 errD_z: 0.45 errG: 2.32
# Epoch:8 Iter: 1500 errD_x: 0.16 errD_z: 0.11 errG: 3.40
# Epoch:8 Iter: 2000 errD_x: 0.20 errD_z: 0.15 errG: 2.41
# Epoch:8 Iter: 2500 errD_x: 0.05 errD_z: 0.22 errG: 3.07
# Epoch:8 Iter: 3000 errD_x: 0.45 errD_z: 0.20 errG: 2.48
# Epoch:8 Iter: 3500 errD_x: 0.39 errD_z: 0.25 errG: 2.26
# Epoch:9 Iter: 500 errD_x: 0.09 errD_z: 0.28 errG: 2.05
# Epoch:9 Iter: 1000 errD_x: 0.11 errD_z: 0.35 errG: 2.14
# Epoch:9 Iter: 1500 errD_x: 0.59 errD_z: 0.16 errG: 2.46
# Epoch:9 Iter: 2000 errD_x: 0.45 errD_z: 0.17 errG: 2.18
# Epoch:9 Iter: 2500 errD_x: 0.06 errD_z: 0.27 errG: 2.68
# Epoch:9 Iter: 3000 errD_x: 0.27 errD_z: 0.42 errG: 1.65
# Epoch:9 Iter: 3500 errD_x: 0.12 errD_z: 0.24 errG: 2.41
# Epoch:10 Iter: 500 errD_x: 0.52 errD_z: 0.44 errG: 1.91
# Epoch:10 Iter: 1000 errD_x: 0.68 errD_z: 0.33 errG: 2.73
# Epoch:10 Iter: 1500 errD_x: 0.30 errD_z: 0.29 errG: 2.09
# Epoch:10 Iter: 2000 errD_x: 0.31 errD_z: 0.35 errG: 2.21
# Epoch:10 Iter: 2500 errD_x: 0.23 errD_z: 0.28 errG: 2.41
# Epoch:10 Iter: 3000 errD_x: 0.23 errD_z: 0.18 errG: 2.25
# Epoch:10 Iter: 3500 errD_x: 0.41 errD_z: 0.26 errG: 2.44

# %%
plt.figure(figsize=(10, 5))
plt.plot(ERRD_x, label="real")
plt.plot(ERRD_z, label="fake")
plt.plot(ERRG, label="generator")
plt.legend()
plt.show()

# %%
noise.data.normal_(0, 1)
fake_labels = torch.LongTensor(list(range(10)) + list(range(6)))

fake = []
for i in range(3):
    noise.data.normal_(0, 1)
    fake.append(generator(noise, fake_labels))

plt.figure(figsize=(15, 15))
for i in range(16):
    for j in range(3):
        plt.subplot(8, 6, 6 * int(i / 2) + 3 * (i % 2) + j + 1)
        plt.imshow(fake[j][i].detach().numpy().reshape(28, 28), cmap=plt.cm.Greys_r)
        plt.axis('off')
